# %%
import pandas as pd
import matplotlib as plt

# %%
dataB = pd.read_excel("F:\\d10\\Projects\\partnerproject\\TEIS_DDA11_DA10-20240126T002836Z-001\\TEIS_DDA11_DA10\\teis-concat-dog\\data\\teis_data.xlsx")

# %%
dataB.head()
# Out:
#   Child ID Gender Date of Birth Location - Sub Level 1  \
# 0    44879      F    2022-09-27              Southwest
# 1    47795      F    2020-12-23      Greater Nashville
# 2    54340      M    2021-06-22        First Tennessee
# 3    54344      F    2022-03-07    Southeast Tennessee
# 4    54515      M    2021-11-04          Memphis Delta
#
#                   Program Label  Adaptive Sum of Scaled Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# ...

# %%
location_groups = {
    'East Tennessee': 'East',
    'First Tennessee': 'East',
    'Southeast Tennessee': 'East',
    'Greater Nashville': 'Middle TN',
    'Upper Cumberland': 'Middle TN',
    'South Central': 'Middle TN',
    'Northwest': 'West',
    'Southwest': 'West',
    'Memphis Delta': 'West'
}


dataB['Location Group'] = dataB['Location_-_Sub_Level_1'].map(location_groups)


dataB['Location Group'].fillna('Other', inplace=True)
# Out:
# C:\Users\seanm\AppData\Local\Temp\ipykernel_13952\825368609.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dataB['Location Group'] = dataB['Location_-_Sub_Level_1'].map(location_groups)

# %%
dataB.head()
# Out:
#   Child_ID Gender Date_of_Birth Location_-_Sub_Level_1  \
# 0    44879      F    2022-09-27              Southwest
# 1    47795      F    2020-12-23      Greater Nashville
# 2    54340      M    2021-06-22        First Tennessee
# 3    54344      F    2022-03-07    Southeast Tennessee
# 4    54515      M    2021-11-04          Memphis Delta
#
#                   Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive_Developmental_Quotient  Adaptive_Percentile_Rank  \
# 0                             85.0                      16.0
# 1                             88.0                      21.0
# 2                             90.0                      25.0
# ...

# %%
scores_grouped_by_location = dataB.groupby('Location Group')

# calculate stats for 'Adaptive Sum of Scaled Scores' as example
score_statsB = scores_grouped_by_location['Adaptive Sum of Scaled Scores'].agg(['mean', 'median', 'std', 'count', 'min', 'max'])

# Display the statistics
print(score_statsB)
# Out:
#                      mean  median       std  count  min   max
# Location Group
# East            11.229919    10.0  5.678463   7781  1.0  33.0
# Middle TN       12.005610    11.0  6.264610  10161  1.0  36.0
# Other           15.303030    14.5  8.074027    132  1.0  31.0
# West            11.828474    11.0  5.834131   5865  1.0  36.0

# %%
# filter for all PR columns
pr_columns = [col for col in data1.columns if 'PR' in col]


for col in pr_columns:
    data1[col] = pd.to_numeric(data1[col], errors='coerce')


location_grouped_data = data1.groupby('Location Group')


pr_stats = {col: location_grouped_data[col].agg(['mean', 'median', 'std', 'count', 'min', 'max']) for col in pr_columns}


for col, stats in pr_stats.items():
    print(f"Statistics for {col}:\n", stats, "\n")
# Out:
# Statistics for Adaptive-Self Care PR:
#                       mean  median        std  count  min   max
# Location Group
# East            29.681293    25.0  24.634754   7179  1.0  99.0
# Middle TN       28.471064    16.0  24.656795   9279  1.0  99.0
# Other           35.232759    25.0  28.714898    116  1.0  95.0
# West            29.553377    25.0  25.534218   5405  1.0  99.0
#
# Statistics for Adaptive-Personal Responsibility PR:
#                       mean  median        std  count  min   max
# Location Group
# East            34.695913    25.0  28.517027   3499  1.0  99.0
# Middle TN       41.433173    37.0  32.084070   5185  1.0  99.0
# Other           60.826087    75.0  35.872365     92  1.0  99.0
# West            38.953883    37.0  29.737612   2949  1.0  99.0
#
# Statistics for Social Emotional-Adult Interaction PR:
#                       mean  median        std  count  min   max
# Location Group
# East            53.521353    50.0  25.785479   7657  1.0  99.0
# ...

# %%
# Selecting columns 6 to 160, which is all of the stats
stats2 = data1.columns[6:161]  


for col in stats2:
    data1[col] = pd.to_numeric(data1[col], errors='coerce')


grouped_data = data1.groupby('Location Group')


columns_stats = {col: grouped_data[col].agg(['mean', 'median', 'std', 'count', 'min', 'max']) for col in stats2}



print(columns_stats)
# Out:
# {'Adaptive Developmental Quotient':                      mean  median        std  count   min    max
# Location Group
# East            86.270659    88.0  17.431150   7781  46.0  140.0
# Middle TN       87.242496    88.0  17.947316  10161  46.0  148.0
# Other           91.636364    94.0  22.581920    132  46.0  133.0
# West            87.395396    88.0  17.416954   5865  46.0  148.0, 'Adaptive Percentile Rank':                      mean  median        std  count  min   max
# Location Group
# East            28.919451    21.0  26.198711   7614  0.1  99.6
# Middle TN       30.447216    25.0  27.638275   9950  0.1  99.9
# Other           42.380645    37.0  34.234041    124  0.1  99.0
# West            30.311982    25.0  27.115924   5767  0.1  99.9, 'Adaptive 95% Confidence Interval':                 mean  median  std  count  min  max
# Location Group
# East             NaN     NaN  NaN      0  NaN  NaN
# Middle TN        NaN     NaN  NaN      0  NaN  NaN
# ...

# %%
location_groups = {
    'East Tennessee': 'East',
    'First Tennessee': 'East',
    'Southeast Tennessee': 'East',
    'Greater Nashville': 'Middle TN',
    'Upper Cumberland': 'Middle TN',
    'South Central': 'Middle TN',
    'Northwest': 'West',
    'Southwest': 'West',
    'Memphis Delta': 'West'
}


dataB['Location Group'] = dataB['Location_-_Sub_Level_1'].map(location_groups)


dataB['Location Group'].fillna('Other', inplace=True)



#drop cases with no data


# dataB.columns = dataB.columns.str.replace(' ', '_')
# dataB.columns = dataB.str.replace('-', '_')
# dataB.columns = dataB.str.replace('__', '_')
# location_check = ['Location__Sub_Level_1']
# drop rows with no location data 
# dataB.dropna(subset=location_check,how='all', inplace=True)
#calculat age at test, convert to years
# dataB['AGE_AT_TEST_YEARS'] = (dataB['TEST_DATE'].dt.year - dataB['Date_of_Birth'].dt.year)

# Selecting columns 6 to 160, which are all of the stats
statsB = dataB.columns[6:161]

# Convert columns to numeric
for col in statsB:
    dataB[col] = pd.to_numeric(dataB[col], errors='coerce')

# Group data by 'Location Group'
loc_grouped_data = dataB.groupby('Location Group')

# Create a new DataFrame to store the statistics
all_da_stats = pd.DataFrame()

# Loop for each column to calc the stats, throw them in a new df
for col in statsB:
    
    stats = loc_grouped_data[col].agg(['mean', 'median', 'std', 'count', 'min', 'max'])
    
    # do the flattening thing so that it doesn't get angry with the column names 
    for stat in stats.columns:
        all_da_stats[f"{col}_{stat}"] = stats[stat]


print(all_da_stats)
# Out:
# C:\Users\seanm\AppData\Local\Temp\ipykernel_13952\408828124.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   all_da_stats[f"{col}_{stat}"] = stats[stat]
# C:\Users\seanm\AppData\Local\Temp\ipykernel_13952\408828124.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   all_da_stats[f"{col}_{stat}"] = stats[stat]
# ...

# %%
all_da_stats.head()
# Out:
#                 Adaptive Developmental Quotient_mean  \
# Location Group
# East                                       86.270659
# Middle TN                                  87.242496
# Other                                      91.636364
# West                                       87.395396
#
#                 Adaptive Developmental Quotient_median  \
# Location Group
# East                                              88.0
# Middle TN                                         88.0
# Other                                             94.0
# West                                              88.0
#
#                 Adaptive Developmental Quotient_std  \
# Location Group
# East                                      17.431150
# Middle TN                                 17.947316
# Other                                     22.581920
# West                                      17.416954
#
#                 Adaptive Developmental Quotient_count  \
# Location Group
# ...

# %%
stats3 = dataB.columns[6:161]

for col in stats3:
    dataB[col] = pd.to_numeric(dataB[col], errors='coerce')

loc_grouped_data = dataB.groupby('Location Group')

comparison_df = pd.DataFrame()

for col in stats3:
    
    comparison_df[col] = loc_grouped_data[col].mean()  

print(comparison_df.head())
# Out:
#                 Adaptive_Developmental_Quotient  Adaptive_Percentile_Rank  \
# Location Group
# East                                  86.270659                 28.919451
# Middle TN                             87.242496                 30.447216
# Other                                 91.636364                 42.380645
# West                                  87.395396                 30.311982
#
#                 Adaptive_95%_Confidence_Interval  Adaptive_RDI  \
# Location Group
# East                                         NaN           NaN
# Middle TN                                    NaN           NaN
# Other                                        NaN           NaN
# West                                         NaN           NaN
#
#                 Adaptive_Z-Score  Adaptive_T-Score  Adaptive_NCE  \
# Location Group
# East                    0.458290         40.848220     37.219964
# Middle TN               0.536481         41.494833     38.039068
# ...

# %%
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        
pd.set_option('display.max_colwidth', None)

comparison_df
# Out:
#                 Adaptive_Developmental_Quotient  Adaptive_Percentile_Rank  \
# Location Group
# East                                  86.270659                 28.919451
# Middle TN                             87.242496                 30.447216
# Other                                 91.636364                 42.380645
# West                                  87.395396                 30.311982
#
#                 Adaptive_95%_Confidence_Interval  Adaptive_RDI  \
# Location Group
# East                                         NaN           NaN
# Middle TN                                    NaN           NaN
# Other                                        NaN           NaN
# West                                         NaN           NaN
#
#                 Adaptive_Z-Score  Adaptive_T-Score  Adaptive_NCE  \
# Location Group
# East                    0.458290         40.848220     37.219964
# Middle TN               0.536481         41.494833     38.039068
# ...

# %%
#create new csv for output
comparison_df.to_csv("comparison_dataframe.csv", index=True)
