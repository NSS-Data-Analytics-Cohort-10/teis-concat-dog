# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset = pd.read_excel(r"C:\Users\AaronH\Documents\nss_data_analytics\Projects\teis-concat-dog\data\BDI3 All Evals for NSS 11-2023.xlsx")

# %%
dataset
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive 95% Confidence Interval         Adaptive RDI  ... Code 1  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code 2 Code 3  Code 4  Code 5 Code 6 Code 7 Code 8 Code 9  Code 10
# 0         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 1         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 2         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 3         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 4         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...       ...    ...     ...     ...    ...    ...    ...    ...      ...
# 23942     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23943     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23944     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23945     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23946     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [23947 rows x 219 columns]

# %% [markdown]
# **DROP DUPLICATES

# %%
dataset_dups_dropped = dataset.drop_duplicates()

# %%
dataset_dups_dropped
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive 95% Confidence Interval         Adaptive RDI  ... Code 1  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code 2 Code 3  Code 4  Code 5 Code 6 Code 7 Code 8 Code 9  Code 10
# 0         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 1         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 2         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 3         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 4         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...       ...    ...     ...     ...    ...    ...    ...    ...      ...
# 23942     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23943     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23944     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23945     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23946     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [19500 rows x 219 columns]

# %% [markdown]
# **CREATE CLEAN DATASET

# %%
dataset_clean = dataset_dups_dropped

# %% [markdown]
# **RENAME COLUMNS

# %%
dataset_clean.columns = dataset_clean.columns.str.replace(' ', '_')

# %%
dataset_clean.columns = dataset_clean.columns.str.replace('-', '_')

# %%
dataset_clean.columns = dataset_clean.columns.str.replace('__', '_')

# %% [markdown]
# **REPLACE MISSING WITH NAN

# %%
dataset_clean.replace('', pd.NA, inplace=True)
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\pandas\core\frame.py:4172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
dataset_clean
# Out:
#       Child_ID Gender Date_of_Birth Location_Sub_Level_1  \
# 0        44879      F    2022-09-27            Southwest
# 1        47795      F    2020-12-23    Greater Nashville
# 2        54340      M    2021-06-22      First Tennessee
# 3        54344      F    2022-03-07  Southeast Tennessee
# 4        54515      M    2021-11-04        Memphis Delta
# ...        ...    ...           ...                  ...
# 23942  SP03287      F    2023-09-25        Memphis Delta
# 23943  SP03288      F    2021-05-18        South Central
# 23944  SP03289      F    2021-10-31        South Central
# 23945  SP03290      M    2020-03-25        Memphis Delta
# 23946  SP03291      M    2023-09-18    Greater Nashville
#
#                       Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_2  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code_3 Code_4  Code_5  Code_6 Code_7 Code_8 Code_9 Code_10  \
# 0         NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 1         NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 2         NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 3         NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 4         NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# ...       ...    ...     ...     ...    ...    ...    ...     ...
# 23942     NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 23943     NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 23944     NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 23945     NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
# 23946     NaN    NaN     NaN     NaN    NaN    NaN    NaN     NaN
#
#        SAME TEST DATE
# 0               False
# 1                True
# 2               False
# 3               False
# 4               False
# ...               ...
# 23942           False
# 23943            True
# 23944            True
# 23945            True
# 23946           False
#
# [19500 rows x 220 columns]

# %% [markdown]
# **DROP CASES WITH NO SCORES

# %%
check_columns = ['Adaptive_Sum_of_Scaled_Scores', 'Social_Emotional_Sum_of_Scaled_Scores', 'Communication_Sum_of_Scaled_Scores', 'Motor_Sum_of_Scaled_Scores', 'Cognitive_Sum_of_Scaled_Scores']

# %%
dataset_clean.dropna(subset=check_columns, how='all', inplace=True)
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_clean
# Out:
#       Child_ID Gender Date_of_Birth Location_Sub_Level_1  \
# 0        44879      F    2022-09-27            Southwest
# 1        47795      F    2020-12-23    Greater Nashville
# 2        54340      M    2021-06-22      First Tennessee
# 3        54344      F    2022-03-07  Southeast Tennessee
# 4        54515      M    2021-11-04        Memphis Delta
# ...        ...    ...           ...                  ...
# 23942  SP03287      F    2023-09-25        Memphis Delta
# 23943  SP03288      F    2021-05-18        South Central
# 23944  SP03289      F    2021-10-31        South Central
# 23945  SP03290      M    2020-03-25        Memphis Delta
# 23946  SP03291      M    2023-09-18    Greater Nashville
#
#                       Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_3  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code_4 Code_5  Code_6  Code_7 Code_8 Code_9 Code_10 SAME TEST DATE  \
# 0         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 1         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 2         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 3         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 4         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# ...       ...    ...     ...     ...    ...    ...     ...            ...
# 23942     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23943     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23944     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23945     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23946     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
#
#        TEST_DATE
# 0     2023-06-23
# 1     2023-03-21
# 2     2023-04-06
# 3     2023-02-23
# 4     2023-02-24
# ...          ...
# 23942 2023-11-15
# 23943 2023-11-13
# 23944 2023-11-14
# 23945 2023-10-26
# 23946 2023-10-24
#
# [19497 rows x 221 columns]

# %% [markdown]
# **CREATE SINGLE TEST DATE COLUMN

# %%
dataset_clean['TEST_DATE'] = dataset_clean['Adaptive_Self_Care_Date_of_Testing']
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_clean
# Out:
#       Child_ID Gender Date_of_Birth Location_Sub_Level_1  \
# 0        44879      F    2022-09-27            Southwest
# 1        47795      F    2020-12-23    Greater Nashville
# 2        54340      M    2021-06-22      First Tennessee
# 3        54344      F    2022-03-07  Southeast Tennessee
# 4        54515      M    2021-11-04        Memphis Delta
# ...        ...    ...           ...                  ...
# 23942  SP03287      F    2023-09-25        Memphis Delta
# 23943  SP03288      F    2021-05-18        South Central
# 23944  SP03289      F    2021-10-31        South Central
# 23945  SP03290      M    2020-03-25        Memphis Delta
# 23946  SP03291      M    2023-09-18    Greater Nashville
#
#                       Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_3  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code_4 Code_5  Code_6  Code_7 Code_8 Code_9 Code_10 SAME TEST DATE  \
# 0         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 1         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 2         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 3         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 4         NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# ...       ...    ...     ...     ...    ...    ...     ...            ...
# 23942     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23943     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23944     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23945     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
# 23946     NaN    NaN     NaN     NaN    NaN    NaN     NaN          False
#
#        TEST_DATE
# 0     2023-06-23
# 1     2023-03-21
# 2     2023-04-06
# 3     2023-02-23
# 4     2023-02-24
# ...          ...
# 23942 2023-11-15
# 23943 2023-11-13
# 23944 2023-11-14
# 23945 2023-10-26
# 23946 2023-10-24
#
# [19497 rows x 221 columns]

# %% [markdown]
# **CHECK FOR MISSING TEST DATES

# %%
date_nan = 'TEST_DATE'

# %%
rows_with_nan_test_date = dataset_clean[dataset_clean[date_nan].isna()]

# %%
rows_with_nan_test_date[]
# Out:
#       Child_ID Gender Date_of_Birth Location_Sub_Level_1  \
# 13301   549646      M    2020-05-02  Southeast Tennessee
# 14721   552599      F    2022-08-27      First Tennessee
# 23271  SP02616      M    2021-08-25        South Central
#
#                       Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 13301  BDI-3 Eligibility Evaluation                            NaN
# 14721  BDI-3 Eligibility Evaluation                            NaN
# 23271  BDI-3 Eligibility Evaluation                            NaN
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 13301                              NaN                      NaN
# 14721                              NaN                      NaN
# 23271                              NaN                      NaN
#
#       Adaptive_95%_Confidence_Interval Adaptive_RDI  ... Code_3  Code_4  \
# 13301                              NaN          NaN  ...    NaN     NaN
# 14721                              NaN          NaN  ...    NaN     NaN
# 23271                              NaN          NaN  ...    NaN     NaN
#
#       Code_5  Code_6  Code_7 Code_8 Code_9 Code_10 SAME TEST DATE  TEST_DATE
# 13301    NaN     NaN     NaN    NaN    NaN     NaN          False        NaT
# 14721    NaN     NaN     NaN    NaN    NaN     NaN          False        NaT
# 23271    NaN     NaN     NaN    NaN    NaN     NaN          False        NaT
#
# [3 rows x 221 columns]

# %%
rows_with_nan_test_date = rows_with_nan_test_date.loc[:, rows_with_nan_test_date.columns.str.contains('Date_of_Testing')]

# %%
rows_with_nan_test_date
# Out:
#       Adaptive_Self_Care_Date_of_Testing  \
# 13301                                NaT
# 14721                                NaT
# 23271                                NaT
#
#       Adaptive_Personal_Responsibility_Date_of_Testing  \
# 13301                                              NaT
# 14721                                              NaT
# 23271                                              NaT
#
#       Social_Emotional_Adult_Interaction_Date_of_Testing  \
# 13301                                                NaT
# 14721                                         2023-05-09
# 23271                                         2023-07-17
#
#       Social_Emotional_Peer_Interaction_Date_of_Testing  \
# 13301                                               NaT
# 14721                                               NaT
# 23271                                               NaT
#
#       Social_Emotional_Self_Concept_/_Social_Role_Date_of_Testing  \
# 13301                                                NaT
# 14721                                         2023-05-09
# 23271                                         2023-07-17
#
#       Communication_Receptive_Communication_Date_of_Testing  \
# 13301                                                NaT
# 14721                                         2023-05-09
# 23271                                                NaT
#
#       Communication_Expressive_Communication_Date_of_Testing  \
# 13301                                                NaT
# 14721                                         2023-05-09
# 23271                                         2023-07-17
#
#       Motor_Gross_Motor_Date_of_Testing Motor_Fine_Motor_Date_of_Testing  \
# 13301                        2023-08-21                       2023-08-21
# 14721                        2023-05-09                       2023-05-09
# 23271                        2023-07-17                       2023-07-17
#
#       Motor_Perceptual_Motor_Date_of_Testing  \
# 13301                             2023-08-21
# 14721                                    NaT
# 23271                                    NaT
#
#       Cognitive_Attention_and_Memory_Date_of_Testing  \
# 13301                                     2023-08-21
# 14721                                     2023-05-09
# 23271                                     2023-07-17
#
#       Cognitive_Reasoning_/_Academic_Skills_Date_of_Testing  \
# 13301                                         2023-08-21
# 14721                                                NaT
# 23271                                                NaT
#
#       Cognitive_Perception_and_Concepts_Date_of_Testing
# 13301                                        2023-08-21
# 14721                                        2023-05-09
# 23271                                               NaT

# %% [markdown]
# **ASSIGN TEST DATE WHERE MISSING

# %%
dataset_clean.at[13301,'TEST_DATE']= pd.to_datetime('2023-08-21')

# %%
dataset_clean.at[14721,'TEST_DATE'] = pd.to_datetime('2023-05-09')

# %%
dataset_clean.at[23271,'TEST_DATE']= pd.to_datetime('2023-07-17')

# %%
rows_with_nan_test_date = dataset_clean[dataset_clean[date_nan].isna()]

# %% [markdown]
# **CHECK FOR MISSING TEST DATE

# %%
rows_with_nan_test_date
# Out:
# Empty DataFrame
# Columns: [Child_ID, Gender, Date_of_Birth, Location_Sub_Level_1, Program_Label, Adaptive_Sum_of_Scaled_Scores, Adaptive_Developmental_Quotient, Adaptive_Percentile_Rank, Adaptive_95%_Confidence_Interval, Adaptive_RDI, Adaptive_Z_Score, Adaptive_T_Score, Adaptive_NCE, Social_Emotional_Sum_of_Scaled_Scores, Social_Emotional_Developmental_Quotient, Social_Emotional_Percentile_Rank, Social_Emotional_95%_Confidence_Interval, Social_Emotional_RDI, Social_Emotional_Z_Score, Social_Emotional_T_Score, Social_Emotional_NCE, Communication_Sum_of_Scaled_Scores, Communication_Developmental_Quotient, Communication_Percentile_Rank, Communication_95%_Confidence_Interval, Communication_RDI, Communication_Z_Score, Communication_T_Score, Communication_NCE, Motor_Sum_of_Scaled_Scores, Motor_Developmental_Quotient, Motor_Percentile_Rank, Motor_95%_Confidence_Interval, Motor_RDI, Motor_Z_Score, Motor_T_Score, Motor_NCE, Cognitive_Sum_of_Scaled_Scores, Cognitive_Developmental_Quotient, Cognitive_Percentile_Rank, Cognitive_95%_Confidence_Interval, Cognitive_RDI, Cognitive_Z_Score, Cognitive_T_Score, Cognitive_NCE, BDI_3_Total_Sum_of_Scaled_Scores, BDI_3_Total_Developmental_Quotient, BDI_3_Total_Percentile_Rank, BDI_3_Total_90%_Confidence_Interval, BDI_3_Total_95%_Confidence_Interval, BDI_3_Total_Z_Score, BDI_3_Total_T_Score, BDI_3_Total_NCE, Adaptive_Self_Care_Examiner, Adaptive_Self_Care_Date_of_Testing, Adaptive_Self_Care_RS, Adaptive_Self_Care_SS, Adaptive_Self_Care_PR, Adaptive_Self_Care_AE, Adaptive_Self_Care_RDI, Adaptive_Self_Care_CSS, Adaptive_Self_Care_CSS_90%, Adaptive_Self_Care_Z_Score, Adaptive_Self_Care_T_Score, Adaptive_Self_Care_NCE, Adaptive_Personal_Responsibility_Examiner, Adaptive_Personal_Responsibility_Date_of_Testing, Adaptive_Personal_Responsibility_RS, Adaptive_Personal_Responsibility_SS, Adaptive_Personal_Responsibility_PR, Adaptive_Personal_Responsibility_AE, Adaptive_Personal_Responsibility_RDI, Adaptive_Personal_Responsibility_CSS, Adaptive_Personal_Responsibility_CSS_90%, Adaptive_Personal_Responsibility_Z_Score, Adaptive_Personal_Responsibility_T_Score, Adaptive_Personal_Responsibility_NCE, Social_Emotional_Adult_Interaction_Examiner, Social_Emotional_Adult_Interaction_Date_of_Testing, Social_Emotional_Adult_Interaction_RS, Social_Emotional_Adult_Interaction_SS, Social_Emotional_Adult_Interaction_PR, Social_Emotional_Adult_Interaction_AE, Social_Emotional_Adult_Interaction_RDI, Social_Emotional_Adult_Interaction_CSS, Social_Emotional_Adult_Interaction_CSS_90%, Social_Emotional_Adult_Interaction_Z_Score, Social_Emotional_Adult_Interaction_T_Score, Social_Emotional_Adult_Interaction_NCE, Social_Emotional_Peer_Interaction_Examiner, Social_Emotional_Peer_Interaction_Date_of_Testing, Social_Emotional_Peer_Interaction_RS, Social_Emotional_Peer_Interaction_SS, Social_Emotional_Peer_Interaction_PR, Social_Emotional_Peer_Interaction_AE, Social_Emotional_Peer_Interaction_RDI, Social_Emotional_Peer_Interaction_CSS, Social_Emotional_Peer_Interaction_CSS_90%, Social_Emotional_Peer_Interaction_Z_Score, Social_Emotional_Peer_Interaction_T_Score, ...]
# Index: []
#
# [0 rows x 221 columns]

# %% [markdown]
# **CREATE AGE COLUMN

# %%
dataset_clean['AGE_AT_TEST_DAYS'] = dataset_clean['TEST_DATE'] - dataset_clean['Date_of_Birth']
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_clean['AGE_AT_TEST_YEARS'] = (dataset_clean['TEST_DATE'].dt.year - dataset_clean['Date_of_Birth'].dt.year)
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_clean
# Out:
#       Child_ID Gender Date_of_Birth Location_Sub_Level_1  \
# 0        44879      F    2022-09-27            Southwest
# 1        47795      F    2020-12-23    Greater Nashville
# 2        54340      M    2021-06-22      First Tennessee
# 3        54344      F    2022-03-07  Southeast Tennessee
# 4        54515      M    2021-11-04        Memphis Delta
# ...        ...    ...           ...                  ...
# 23942  SP03287      F    2023-09-25        Memphis Delta
# 23943  SP03288      F    2021-05-18        South Central
# 23944  SP03289      F    2021-10-31        South Central
# 23945  SP03290      M    2020-03-25        Memphis Delta
# 23946  SP03291      M    2023-09-18    Greater Nashville
#
#                       Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_7  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code_8 Code_9  Code_10  SAME TEST DATE  TEST_DATE AGE_AT_TEST  \
# 0         NaN    NaN      NaN           False 2023-06-23    269 days
# 1         NaN    NaN      NaN           False 2023-03-21    818 days
# 2         NaN    NaN      NaN           False 2023-04-06    653 days
# 3         NaN    NaN      NaN           False 2023-02-23    353 days
# 4         NaN    NaN      NaN           False 2023-02-24    477 days
# ...       ...    ...      ...             ...        ...         ...
# 23942     NaN    NaN      NaN           False 2023-11-15     51 days
# 23943     NaN    NaN      NaN           False 2023-11-13    909 days
# 23944     NaN    NaN      NaN           False 2023-11-14    744 days
# 23945     NaN    NaN      NaN           False 2023-10-26   1310 days
# 23946     NaN    NaN      NaN           False 2023-10-24     36 days
#
#       AGE_AT_TEST_NUMERIC AGE_AT_TEST_DAYS  AGE_AT_TEST_YEARS
# 0                0.736497         269 days                  1
# 1                2.239608         818 days                  3
# 2                1.787853         653 days                  2
# 3                0.966481         353 days                  1
# 4                1.305982         477 days                  2
# ...                   ...              ...                ...
# 23942            0.139633          51 days                  0
# 23943            2.488757         909 days                  2
# 23944            2.037003         744 days                  2
# 23945            3.586658        1310 days                  3
# 23946            0.098565          36 days                  0
#
# [19497 rows x 225 columns]

# %% [markdown]
# **CREATE PERCENTILE RANK COLUMN

# %% [markdown]
# **CREATE REGION COLUMN

# %%
dataset_clean['Region'] = dataset_clean['Location_Sub_Level_1']

# %%
dataset_clean
# Out:
#       Child_ID Gender Date_of_Birth Location_Sub_Level_1  \
# 0        44879      F    2022-09-27            Southwest
# 1        47795      F    2020-12-23    Greater Nashville
# 2        54340      M    2021-06-22      First Tennessee
# 3        54344      F    2022-03-07  Southeast Tennessee
# 4        54515      M    2021-11-04        Memphis Delta
# ...        ...    ...           ...                  ...
# 23942  SP03287      F    2023-09-25        Memphis Delta
# 23943  SP03288      F    2021-05-18        South Central
# 23944  SP03289      F    2021-10-31        South Central
# 23945  SP03290      M    2020-03-25        Memphis Delta
# 23946  SP03291      M    2023-09-18    Greater Nashville
#
#                       Program_Label  Adaptive_Sum_of_Scaled_Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23945       BDI-3 Annual Evaluation                           16.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive_Developmental_Quotient Adaptive_Percentile_Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23945                             88.0                       21
# 23946                            105.0                       63
#
#       Adaptive_95%_Confidence_Interval         Adaptive_RDI  ... Code_8  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23945                            82-96                66/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code_9 Code_10  SAME TEST DATE  TEST_DATE AGE_AT_TEST  \
# 0         NaN     NaN           False 2023-06-23    269 days
# 1         NaN     NaN           False 2023-03-21    818 days
# 2         NaN     NaN           False 2023-04-06    653 days
# 3         NaN     NaN           False 2023-02-23    353 days
# 4         NaN     NaN           False 2023-02-24    477 days
# ...       ...     ...             ...        ...         ...
# 23942     NaN     NaN           False 2023-11-15     51 days
# 23943     NaN     NaN           False 2023-11-13    909 days
# 23944     NaN     NaN           False 2023-11-14    744 days
# 23945     NaN     NaN           False 2023-10-26   1310 days
# 23946     NaN     NaN           False 2023-10-24     36 days
#
#       AGE_AT_TEST_NUMERIC AGE_AT_TEST_DAYS AGE_AT_TEST_YEARS  \
# 0                0.736497         269 days                 1
# 1                2.239608         818 days                 3
# 2                1.787853         653 days                 2
# 3                0.966481         353 days                 1
# 4                1.305982         477 days                 2
# ...                   ...              ...               ...
# 23942            0.139633          51 days                 0
# 23943            2.488757         909 days                 2
# 23944            2.037003         744 days                 2
# 23945            3.586658        1310 days                 3
# 23946            0.098565          36 days                 0
#
#                     Region
# 0                Southwest
# 1        Greater Nashville
# 2          First Tennessee
# 3      Southeast Tennessee
# 4            Memphis Delta
# ...                    ...
# 23942        Memphis Delta
# 23943        South Central
# 23944        South Central
# 23945        Memphis Delta
# 23946    Greater Nashville
#
# [19497 rows x 226 columns]

# %% [markdown]
# **WEST TN REGION

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('Northwest','West_TN')

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('Southwest','West_TN')

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('Memphis Delta','West_TN')

# %% [markdown]
# **MIDDLE TN REGION

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('Upper Cumberland','Middle_TN')

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('Greater Nashville','Middle_TN')

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('South Central','Middle_TN')

# %% [markdown]
# **EAST TN REGION

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('First Tennessee','East_TN')

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('East Tennessee','East_TN')

# %%
dataset_clean['Region'] = dataset_clean['Region'].str.replace('Southeast Tennessee','East_TN')

# %%
dataset_clean.groupby('Region')[['Adaptive_Sum_of_Scaled_Scores','Social_Emotional_Sum_of_Scaled_Scores','Communication_Sum_of_Scaled_Scores','Motor_Sum_of_Scaled_Scores','Cognitive_Sum_of_Scaled_Scores']].mean()
# Out:
#            Adaptive_Sum_of_Scaled_Scores  \
# Region
# East_TN                        10.966923
# Middle_TN                      11.621834
# West_TN                        11.605660
#
#            Social_Emotional_Sum_of_Scaled_Scores  \
# Region
# East_TN                                21.485110
# Middle_TN                              22.313951
# West_TN                                23.664361
#
#            Communication_Sum_of_Scaled_Scores  Motor_Sum_of_Scaled_Scores  \
# Region
# East_TN                             13.688654                   22.452374
# Middle_TN                           12.945048                   22.471264
# West_TN                             12.990145                   23.235639
#
#            Cognitive_Sum_of_Scaled_Scores
# Region
# East_TN                         20.516397
# Middle_TN                       19.924354
# West_TN                         20.327463

# %% [markdown]
# **IGNORE

# %%
df_scaled_scores_domains = dataset_clean.filter(regex='Sum of Scaled Scores')

# %%
df_scaled_scores_domains.describe()
# Out:
#        Adaptive Sum of Scaled Scores  Social-Emotional Sum of Scaled Scores  \
# count                   19493.000000                           19483.000000
# mean                       11.412712                              22.381153
# std                         5.822943                               7.519204
# min                         1.000000                               2.000000
# 25%                         7.000000                              17.000000
# 50%                        11.000000                              22.000000
# 75%                        15.000000                              28.000000
# max                        36.000000                              53.000000
#
#        Communication Sum of Scaled Scores  Motor Sum of Scaled Scores  \
# count                          19469.0000                19471.000000
# mean                              13.2015                   22.655334
# std                                6.7228                    8.067995
# min                                2.0000                    2.000000
# 25%                                8.0000                   17.000000
# 50%                               13.0000                   22.000000
# 75%                               18.0000                   28.000000
# max                               38.0000                   50.000000
#
#        Cognitive Sum of Scaled Scores  BDI-3 Total Sum of Scaled Scores
# count                    19481.000000                      19443.000000
# mean                        20.220933                         89.863036
# std                          6.955015                         28.293704
# min                          2.000000                          9.000000
# 25%                         16.000000                         71.000000
# 50%                         20.000000                         88.000000
# 75%                         24.000000                        107.000000
# max                         54.000000                        199.000000

# %%
df_scaled_scores_subdomains = dataset_clean.filter(regex='SS')

# %%
df_scaled_scores_subdomains
# Out:
#        Adaptive-Self Care SS  Adaptive-Self Care CSS  \
# 0                        7.0                   377.0
# 1                        7.0                   471.0
# 2                        8.0                   466.0
# 3                       13.0                   449.0
# 4                        5.0                   412.0
# ...                      ...                     ...
# 23942                   13.0                   325.0
# 23943                   10.0                   489.0
# 23944                   10.0                   486.0
# 23945                    6.0                   489.0
# 23946                   11.0                   302.0
#
#       Adaptive-Self Care CSS 90%  Adaptive-Personal Responsibility SS  \
# 0                      363 - 391                                  NaN
# 1                      464 - 478                                  9.0
# 2                      459 - 474                                  NaN
# 3                      439 - 459                                  NaN
# 4                      397 - 426                                  NaN
# ...                          ...                                  ...
# 23942                  286 - 364                                  NaN
# 23943                  481 - 496                                 15.0
# 23944                  479 - 494                                 11.0
# 23945                  481 - 496                                 10.0
# 23946                  286 - 319                                  NaN
#
#        Adaptive-Personal Responsibility CSS  \
# 0                                       NaN
# 1                                     484.0
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 23942                                   NaN
# 23943                                 513.0
# 23944                                 490.0
# 23945                                 507.0
# 23946                                   NaN
#
#       Adaptive-Personal Responsibility CSS 90%  \
# 0                                          NaN
# 1                                    476 - 493
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 23942                                      NaN
# 23943                                506 - 520
# 23944                                482 - 499
# 23945                                500 - 514
# 23946                                      NaN
#
#        Social Emotional-Adult Interaction SS  \
# 0                                       14.0
# 1                                       12.0
# 2                                       11.0
# 3                                       10.0
# 4                                        6.0
# ...                                      ...
# 23942                                   13.0
# 23943                                   12.0
# 23944                                   12.0
# 23945                                    8.0
# 23946                                    9.0
#
#        Social Emotional-Adult Interaction CSS  \
# 0                                       478.0
# 1                                       506.0
# 2                                       495.0
# 3                                       471.0
# 4                                       450.0
# ...                                       ...
# 23942                                   435.0
# 23943                                   506.0
# 23944                                   506.0
# 23945                                   492.0
# 23946                                   408.0
#
#       Social Emotional-Adult Interaction CSS 90%  \
# 0                                      470 - 485
# 1                                      499 - 514
# 2                                      487 - 502
# 3                                      464 - 479
# 4                                      441 - 458
# ...                                          ...
# 23942                                  425 - 445
# 23943                                  499 - 514
# 23944                                  499 - 514
# 23945                                  484 - 500
# 23946                                  396 - 421
#
#        Social Emotional-Peer Interaction SS  ...  \
# 0                                       NaN  ...
# 1                                       9.0  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       NaN  ...
# ...                                     ...  ...
# 23942                                   NaN  ...
# 23943                                  13.0  ...
# 23944                                  10.0  ...
# 23945                                  11.0  ...
# 23946                                   NaN  ...
#
#        Motor-Perceptual Motor CSS 90%  Cognitive-Attention and Memory SS  \
# 0                                  NaN                               7.0
# 1                            460 - 500                               9.0
# 2                                  NaN                               8.0
# 3                                  NaN                              14.0
# 4                                  NaN                               9.0
# ...                                ...                               ...
# 23942                              NaN                               9.0
# 23943                        488 - 511                              13.0
# 23944                        460 - 500                              10.0
# 23945                        513 - 537                               7.0
# 23946                              NaN                               7.0
#
#        Cognitive-Attention and Memory CSS  \
# 0                                   423.0
# 1                                   482.0
# 2                                   468.0
# 3                                   475.0
# 4                                   464.0
# ...                                   ...
# 23942                               381.0
# 23943                               502.0
# 23944                               485.0
# 23945                               485.0
# 23946                               366.0
#
#        Cognitive-Attention and Memory CSS 90%  \
# 0                                   413 - 432
# 1                                   473 - 491
# 2                                   458 - 477
# 3                                   466 - 485
# 4                                   455 - 473
# ...                                       ...
# 23942                               369 - 393
# 23943                               494 - 511
# 23944                               476 - 495
# 23945                               476 - 495
# 23946                               342 - 389
#
#       Cognitive-Reasoning / Academic Skills SS  \
# 0                                          NaN
# 1                                         14.0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 23942                                      NaN
# 23943                                     14.0
# 23944                                      9.0
# 23945                                      8.0
# 23946                                      NaN
#
#        Cognitive-Reasoning / Academic Skills CSS  \
# 0                                            NaN
# 1                                          498.0
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 23942                                        NaN
# 23943                                      504.0
# 23944                                      482.0
# 23945                                      498.0
# 23946                                        NaN
#
#        Cognitive-Reasoning / Academic Skills CSS 90%  \
# 0                                                NaN
# 1                                          489 - 507
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 23942                                            NaN
# 23943                                      496 - 513
# 23944                                      473 - 491
# 23945                                      489 - 507
# 23946                                            NaN
#
#       Cognitive-Perception and Concepts SS  \
# 0                                     13.0
# 1                                      7.0
# 2                                      7.0
# 3                                     10.0
# 4                                     10.0
# ...                                    ...
# 23942                                 15.0
# 23943                                 14.0
# 23944                                 10.0
# 23945                                  9.0
# 23946                                 12.0
#
#        Cognitive-Perception and Concepts CSS  \
# 0                                      411.0
# 1                                      437.0
# 2                                      426.0
# 3                                      411.0
# 4                                      426.0
# ...                                      ...
# 23942                                  378.0
# 23943                                  499.0
# 23944                                  464.0
# 23945                                  507.0
# 23946                                  352.0
#
#        Cognitive-Perception and Concepts CSS 90%
# 0                                      392 - 431
# 1                                      421 - 453
# 2                                      408 - 444
# 3                                      392 - 431
# 4                                      408 - 444
# ...                                          ...
# 23942                                  365 - 391
# 23943                                  491 - 508
# 23944                                  450 - 479
# 23945                                  500 - 515
# 23946                                  323 - 381
#
# [19500 rows x 39 columns]

# %%
df_scaled_scores_subdomains_final = df_scaled_scores_subdomains.loc[:, ~df_scaled_scores_subdomains.columns.str.contains('CSS')]

# %%
df_scaled_scores_subdomains_final
# Out:
#        Adaptive-Self Care SS  Adaptive-Personal Responsibility SS  \
# 0                        7.0                                  NaN
# 1                        7.0                                  9.0
# 2                        8.0                                  NaN
# 3                       13.0                                  NaN
# 4                        5.0                                  NaN
# ...                      ...                                  ...
# 23942                   13.0                                  NaN
# 23943                   10.0                                 15.0
# 23944                   10.0                                 11.0
# 23945                    6.0                                 10.0
# 23946                   11.0                                  NaN
#
#        Social Emotional-Adult Interaction SS  \
# 0                                       14.0
# 1                                       12.0
# 2                                       11.0
# 3                                       10.0
# 4                                        6.0
# ...                                      ...
# 23942                                   13.0
# 23943                                   12.0
# 23944                                   12.0
# 23945                                    8.0
# 23946                                    9.0
#
#        Social Emotional-Peer Interaction SS  \
# 0                                       NaN
# 1                                       9.0
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 23942                                   NaN
# 23943                                  13.0
# 23944                                  10.0
# 23945                                  11.0
# 23946                                   NaN
#
#        Social Emotional-Self Concept / Social Role SS  \
# 0                                                15.0
# 1                                                11.0
# 2                                                 6.0
# 3                                                11.0
# 4                                                 5.0
# ...                                               ...
# 23942                                            12.0
# 23943                                            13.0
# 23944                                             9.0
# 23945                                             6.0
# 23946                                            10.0
#
#        Communication-Receptive Communication SS  \
# 0                                           8.0
# 1                                          10.0
# 2                                           7.0
# 3                                           8.0
# 4                                           5.0
# ...                                         ...
# 23942                                      12.0
# 23943                                      14.0
# 23944                                       4.0
# 23945                                       7.0
# 23946                                       8.0
#
#        Communication-Expressive Communication SS  Motor-Gross Motor SS  \
# 0                                            9.0                   7.0
# 1                                            9.0                   7.0
# 2                                            7.0                  11.0
# 3                                            8.0                   5.0
# 4                                            5.0                   3.0
# ...                                          ...                   ...
# 23942                                       12.0                  11.0
# 23943                                       10.0                  15.0
# 23944                                        1.0                  11.0
# 23945                                        5.0                   9.0
# 23946                                       12.0                   8.0
#
#        Motor-Fine Motor SS  Motor-Perceptual Motor SS  \
# 0                      9.0                        NaN
# 1                     13.0                       11.0
# 2                     12.0                        NaN
# 3                     12.0                        NaN
# 4                      8.0                        NaN
# ...                    ...                        ...
# 23942                 15.0                        NaN
# 23943                 11.0                       12.0
# 23944                 10.0                       11.0
# 23945                 10.0                       11.0
# 23946                 12.0                        NaN
#
#        Cognitive-Attention and Memory SS  \
# 0                                    7.0
# 1                                    9.0
# 2                                    8.0
# 3                                   14.0
# 4                                    9.0
# ...                                  ...
# 23942                                9.0
# 23943                               13.0
# 23944                               10.0
# 23945                                7.0
# 23946                                7.0
#
#        Cognitive-Reasoning / Academic Skills SS  \
# 0                                           NaN
# 1                                          14.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 23942                                       NaN
# 23943                                      14.0
# 23944                                       9.0
# 23945                                       8.0
# 23946                                       NaN
#
#        Cognitive-Perception and Concepts SS
# 0                                      13.0
# 1                                       7.0
# 2                                       7.0
# 3                                      10.0
# 4                                      10.0
# ...                                     ...
# 23942                                  15.0
# 23943                                  14.0
# 23944                                  10.0
# 23945                                   9.0
# 23946                                  12.0
#
# [19500 rows x 13 columns]

# %%
df_scaled_scores_subdomains_final.describe()
# Out:
#        Adaptive-Self Care SS  Adaptive-Personal Responsibility SS  \
# count           19494.000000                          9698.000000
# mean                7.453832                             7.957826
# std                 3.144153                             3.861019
# min                 1.000000                             1.000000
# 25%                 6.000000                             5.000000
# 50%                 7.000000                             8.000000
# 75%                10.000000                            11.000000
# max                19.000000                            19.000000
#
#        Social Emotional-Adult Interaction SS  \
# count                           19489.000000
# mean                               10.452409
# std                                 2.834861
# min                                 1.000000
# 25%                                 9.000000
# 50%                                11.000000
# 75%                                12.000000
# max                                19.000000
#
#        Social Emotional-Peer Interaction SS  \
# count                           9694.000000
# mean                               7.834124
# std                                3.298726
# min                                1.000000
# 25%                                5.000000
# 50%                                8.000000
# 75%                               10.000000
# max                               19.000000
#
#        Social Emotional-Self Concept / Social Role SS  \
# count                                    19486.000000
# mean                                         8.032793
# std                                          3.298105
# min                                          1.000000
# 25%                                          6.000000
# 50%                                          8.000000
# 75%                                         10.000000
# max                                         19.000000
#
#        Communication-Receptive Communication SS  \
# count                              19485.000000
# mean                                   6.709110
# std                                    3.622658
# min                                    1.000000
# 25%                                    4.000000
# 50%                                    7.000000
# 75%                                    9.000000
# max                                   19.000000
#
#        Communication-Expressive Communication SS  Motor-Gross Motor SS  \
# count                               19472.000000          19483.000000
# mean                                    6.493991              8.621568
# std                                     3.672590              3.042683
# min                                     1.000000              1.000000
# 25%                                     4.000000              7.000000
# 50%                                     6.000000              9.000000
# 75%                                     9.000000             11.000000
# max                                    19.000000             19.000000
#
#        Motor-Fine Motor SS  Motor-Perceptual Motor SS  \
# count         19481.000000                9688.000000
# mean              9.783430                   8.545417
# std               3.191053                   3.924365
# min               1.000000                   1.000000
# 25%               8.000000                   6.000000
# 50%              10.000000                   9.000000
# 75%              12.000000                  11.000000
# max              19.000000                  19.000000
#
#        Cognitive-Attention and Memory SS  \
# count                       19484.000000
# mean                            8.407206
# std                             2.714675
# min                             1.000000
# 25%                             7.000000
# 50%                             9.000000
# 75%                            10.000000
# max                            19.000000
#
#        Cognitive-Reasoning / Academic Skills SS  \
# count                               9693.000000
# mean                                   8.097803
# std                                    3.203242
# min                                    1.000000
# 25%                                    6.000000
# 50%                                    8.000000
# 75%                                   11.000000
# max                                   19.000000
#
#        Cognitive-Perception and Concepts SS
# count                          19482.000000
# mean                               7.785443
# std                                3.259881
# min                                1.000000
# 25%                                6.000000
# 50%                                8.000000
# 75%                               10.000000
# max                               19.000000

# %%
dataset_clean.groupby('Program Label')['Child ID'].count()
# Out:
# Program Label
# BDI-3 Annual Evaluation                6905
# BDI-3 Eligibility Evaluation          12392
# BDI-3 Milestone or Exit Evaluation      203
# Name: Child ID, dtype: int64

# %%
dataset_annual_evaluation = dataset_clean[dataset_clean['Program Label']=='BDI-3 Annual Evaluation']

# %%
dataset_annual_evaluation
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 19      404042      M    2020-03-17       Upper Cumberland
# 21      419577      F    2021-12-21         East Tennessee
# 24      474074      F    2019-11-14      Greater Nashville
# 26      474186      F    2019-11-03      Greater Nashville
# 27      474641      M    2019-10-29       Upper Cumberland
# ...        ...    ...           ...                    ...
# 23190  SP02535      F    2021-12-22          Memphis Delta
# 23191  SP02536      F    2022-09-26       Upper Cumberland
# 23192  SP02537      F    2022-11-02          South Central
# 23193  SP02538      M    2021-12-16    Southeast Tennessee
# 23945  SP03290      M    2020-03-25          Memphis Delta
#
#                  Program Label  Adaptive Sum of Scaled Scores  \
# 19     BDI-3 Annual Evaluation                            2.0
# 21     BDI-3 Annual Evaluation                            9.0
# 24     BDI-3 Annual Evaluation                           21.0
# 26     BDI-3 Annual Evaluation                           24.0
# 27     BDI-3 Annual Evaluation                           16.0
# ...                        ...                            ...
# 23190  BDI-3 Annual Evaluation                            6.0
# 23191  BDI-3 Annual Evaluation                            8.0
# 23192  BDI-3 Annual Evaluation                            9.0
# 23193  BDI-3 Annual Evaluation                            1.0
# 23945  BDI-3 Annual Evaluation                           16.0
#
#        Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 19                                46.0                     <0.1
# 21                                95.0                       37
# 24                               103.0                       58
# 26                               112.0                       79
# 27                                88.0                       21
# ...                                ...                      ...
# 23190                             80.0                        9
# 23191                             90.0                       25
# 23192                             95.0                       37
# 23193                             55.0                      0.1
# 23945                             88.0                       21
#
#       Adaptive 95% Confidence Interval Adaptive RDI  ... Code 1  Code 2  \
# 19                               42-56        <1/90  ...    NaN     NaN
# 21                              86-106        79/90  ...    NaN     NaN
# 24                              96-110        88/90  ...    NaN     NaN
# 26                             104-118        96/90  ...    NaN     NaN
# 27                               82-96        68/90  ...    NaN     NaN
# ...                                ...          ...  ...    ...     ...
# 23190                            73-93        19/90  ...    NaN     NaN
# 23191                           81-101        66/90  ...    NaN     NaN
# 23192                           86-106        79/90  ...    NaN     NaN
# 23193                            51-71        <1/90  ...    NaN     NaN
# 23945                            82-96        66/90  ...    NaN     NaN
#
#       Code 3  Code 4  Code 5 Code 6 Code 7 Code 8 Code 9  Code 10
# 19       NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 21       NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 24       NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 26       NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 27       NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...      ...     ...     ...    ...    ...    ...    ...      ...
# 23190    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23191    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23192    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23193    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23945    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [6905 rows x 219 columns]

# %%
dataset_eligibility_evaluation = dataset_clean[dataset_clean['Program Label']=='BDI-3 Eligibility Evaluation']

# %%
dataset_eligibility_evaluation
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23941  SP03286      F    2021-08-16          Memphis Delta
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23941  BDI-3 Eligibility Evaluation                           30.0
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23941                            130.0                       98
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23946                            105.0                       63
#
#       Adaptive 95% Confidence Interval         Adaptive RDI  ... Code 1  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23941                          121-135                99/90  ...    NaN
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code 2 Code 3  Code 4  Code 5 Code 6 Code 7 Code 8 Code 9  Code 10
# 0         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 1         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 2         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 3         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 4         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...       ...    ...     ...     ...    ...    ...    ...    ...      ...
# 23941     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23942     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23943     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23944     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23946     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [12392 rows x 219 columns]

# %%
dataset_exit_evaluation = dataset_clean[dataset_clean['Program Label']=='BDI-3 Milestone or Exit Evaluation']

# %%
dataset_exit_evaluation
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 60      478244      F    2019-12-04       Upper Cumberland
# 111     481710      M    2020-03-31              Northwest
# 115     481768      F    2020-03-07       Upper Cumberland
# 123     482146      M    2020-04-07       Upper Cumberland
# 147     483511      F    2020-05-09    Southeast Tennessee
# ...        ...    ...           ...                    ...
# 23025  SP02370      M    2020-11-14         East Tennessee
# 23026  SP02371      F    2021-02-06          Memphis Delta
# 23027  SP02372      F    2020-09-06          Memphis Delta
# 23028  SP02373      M    2020-11-22         East Tennessee
# 23029  SP02374      M    2020-12-02         East Tennessee
#
#                             Program Label  Adaptive Sum of Scaled Scores  \
# 60     BDI-3 Milestone or Exit Evaluation                            7.0
# 111    BDI-3 Milestone or Exit Evaluation                           19.0
# 115    BDI-3 Milestone or Exit Evaluation                           28.0
# 123    BDI-3 Milestone or Exit Evaluation                            4.0
# 147    BDI-3 Milestone or Exit Evaluation                           27.0
# ...                                   ...                            ...
# 23025  BDI-3 Milestone or Exit Evaluation                           16.0
# 23026  BDI-3 Milestone or Exit Evaluation                           10.0
# 23027  BDI-3 Milestone or Exit Evaluation                           10.0
# 23028  BDI-3 Milestone or Exit Evaluation                            9.0
# 23029  BDI-3 Milestone or Exit Evaluation                           13.0
#
#        Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 60                                61.0                        1
# 111                               97.0                       42
# 115                              124.0                       95
# 123                               52.0                      0.1
# 147                              121.0                       92
# ...                                ...                      ...
# 23025                             88.0                       21
# 23026                             70.0                        2
# 23027                             70.0                        2
# 23028                             67.0                        1
# 23029                             79.0                        8
#
#       Adaptive 95% Confidence Interval         Adaptive RDI  ... Code 1  \
# 60                               56-70                18/90  ...    NaN
# 111                             90-104                88/90  ...    NaN
# 115                            116-130                98/90  ...    NaN
# 123                              48-62  1990-05-01 00:00:00  ...    NaN
# 147                            113-127                98/90  ...    NaN
# ...                                ...                  ...  ...    ...
# 23025                            82-96                75/90  ...    NaN
# 23026                            65-79                34/90  ...    NaN
# 23027                            65-79                29/90  ...    NaN
# 23028                            62-76                29/90  ...    NaN
# 23029                            73-87                55/90  ...    NaN
#
#        Code 2 Code 3  Code 4  Code 5 Code 6 Code 7 Code 8 Code 9  Code 10
# 60        NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 111       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 115       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 123       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 147       NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...       ...    ...     ...     ...    ...    ...    ...    ...      ...
# 23025     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23026     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23027     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23028     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23029     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [203 rows x 219 columns]

# %%
dataset_eligibility_evaluation
# Out:
#       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23941  SP03286      F    2021-08-16          Memphis Delta
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# 2      BDI-3 Eligibility Evaluation                            8.0
# 3      BDI-3 Eligibility Evaluation                           13.0
# 4      BDI-3 Eligibility Evaluation                            5.0
# ...                             ...                            ...
# 23941  BDI-3 Eligibility Evaluation                           30.0
# 23942  BDI-3 Eligibility Evaluation                           13.0
# 23943  BDI-3 Eligibility Evaluation                           25.0
# 23944  BDI-3 Eligibility Evaluation                           21.0
# 23946  BDI-3 Eligibility Evaluation                           11.0
#
#        Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                                 85.0                       16
# 1                                 88.0                       21
# 2                                 90.0                       25
# 3                                115.0                       84
# 4                                 75.0                        5
# ...                                ...                      ...
# 23941                            130.0                       98
# 23942                            115.0                       84
# 23943                            115.0                       84
# 23944                            103.0                       58
# 23946                            105.0                       63
#
#       Adaptive 95% Confidence Interval         Adaptive RDI  ... Code 1  \
# 0                                77-97                39/90  ...    NaN
# 1                                82-96                79/90  ...    NaN
# 2                               81-101                77/90  ...    NaN
# 3                              103-123                99/90  ...    NaN
# 4                                68-88  1990-09-01 00:00:00  ...    NaN
# ...                                ...                  ...  ...    ...
# 23941                          121-135                99/90  ...    NaN
# 23942                          103-123                99/90  ...    NaN
# 23943                          107-121                96/90  ...    NaN
# 23944                           96-110                92/90  ...    NaN
# 23946                           94-114                94/90  ...    NaN
#
#        Code 2 Code 3  Code 4  Code 5 Code 6 Code 7 Code 8 Code 9  Code 10
# 0         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 1         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 2         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 3         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 4         NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# ...       ...    ...     ...     ...    ...    ...    ...    ...      ...
# 23941     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23942     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23943     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23944     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
# 23946     NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN      NaN
#
# [12392 rows x 219 columns]

# %%
dataset_eligibility_evaluation_subdomains = dataset_eligibility_evaluation.loc[:, ~dataset_eligibility_evaluation.columns.str.contains('CSS')]

# %%
dataset_eligibility_evaluation_subdomains = dataset_eligibility_evaluation_corr.loc[:, dataset_eligibility_evaluation_corr.columns.str.contains('SS')]

# %%
dataset_eligibility_evaluation_subdomains
# Out:
#        Adaptive-Self Care SS  Adaptive-Personal Responsibility SS  \
# 0                        7.0                                  NaN
# 1                        7.0                                  9.0
# 2                        8.0                                  NaN
# 3                       13.0                                  NaN
# 4                        5.0                                  NaN
# ...                      ...                                  ...
# 23941                   17.0                                 13.0
# 23942                   13.0                                  NaN
# 23943                   10.0                                 15.0
# 23944                   10.0                                 11.0
# 23946                   11.0                                  NaN
#
#        Social Emotional-Adult Interaction SS  \
# 0                                       14.0
# 1                                       12.0
# 2                                       11.0
# 3                                       10.0
# 4                                        6.0
# ...                                      ...
# 23941                                   12.0
# 23942                                   13.0
# 23943                                   12.0
# 23944                                   12.0
# 23946                                    9.0
#
#        Social Emotional-Peer Interaction SS  \
# 0                                       NaN
# 1                                       9.0
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 23941                                  12.0
# 23942                                   NaN
# 23943                                  13.0
# 23944                                  10.0
# 23946                                   NaN
#
#        Social Emotional-Self Concept / Social Role SS  \
# 0                                                15.0
# 1                                                11.0
# 2                                                 6.0
# 3                                                11.0
# 4                                                 5.0
# ...                                               ...
# 23941                                             4.0
# 23942                                            12.0
# 23943                                            13.0
# 23944                                             9.0
# 23946                                            10.0
#
#        Communication-Receptive Communication SS  \
# 0                                           8.0
# 1                                          10.0
# 2                                           7.0
# 3                                           8.0
# 4                                           5.0
# ...                                         ...
# 23941                                      10.0
# 23942                                      12.0
# 23943                                      14.0
# 23944                                       4.0
# 23946                                       8.0
#
#        Communication-Expressive Communication SS  Motor-Gross Motor SS  \
# 0                                            9.0                   7.0
# 1                                            9.0                   7.0
# 2                                            7.0                  11.0
# 3                                            8.0                   5.0
# 4                                            5.0                   3.0
# ...                                          ...                   ...
# 23941                                        7.0                  10.0
# 23942                                       12.0                  11.0
# 23943                                       10.0                  15.0
# 23944                                        1.0                  11.0
# 23946                                       12.0                   8.0
#
#        Motor-Fine Motor SS  Motor-Perceptual Motor SS  \
# 0                      9.0                        NaN
# 1                     13.0                       11.0
# 2                     12.0                        NaN
# 3                     12.0                        NaN
# 4                      8.0                        NaN
# ...                    ...                        ...
# 23941                 14.0                       14.0
# 23942                 15.0                        NaN
# 23943                 11.0                       12.0
# 23944                 10.0                       11.0
# 23946                 12.0                        NaN
#
#        Cognitive-Attention and Memory SS  \
# 0                                    7.0
# 1                                    9.0
# 2                                    8.0
# 3                                   14.0
# 4                                    9.0
# ...                                  ...
# 23941                                9.0
# 23942                                9.0
# 23943                               13.0
# 23944                               10.0
# 23946                                7.0
#
#        Cognitive-Reasoning / Academic Skills SS  \
# 0                                           NaN
# 1                                          14.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 23941                                      13.0
# 23942                                       NaN
# 23943                                      14.0
# 23944                                       9.0
# 23946                                       NaN
#
#        Cognitive-Perception and Concepts SS
# 0                                      13.0
# 1                                       7.0
# 2                                       7.0
# 3                                      10.0
# 4                                      10.0
# ...                                     ...
# 23941                                  13.0
# 23942                                  15.0
# 23943                                  14.0
# 23944                                  10.0
# 23946                                  12.0
#
# [12392 rows x 13 columns]

# %%
dataset_eligibility_evaluation_corr_final['standard_deviation'] = dataset_eligibility_evaluation_corr_final.std(axis=1, numeric_only=True)
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_eligibility_evaluation_corr_final
# Out:
#        Adaptive-Self Care SS  Adaptive-Personal Responsibility SS  \
# 0                        7.0                                  NaN
# 1                        7.0                                  9.0
# 2                        8.0                                  NaN
# 3                       13.0                                  NaN
# 4                        5.0                                  NaN
# ...                      ...                                  ...
# 23941                   17.0                                 13.0
# 23942                   13.0                                  NaN
# 23943                   10.0                                 15.0
# 23944                   10.0                                 11.0
# 23946                   11.0                                  NaN
#
#        Social Emotional-Adult Interaction SS  \
# 0                                       14.0
# 1                                       12.0
# 2                                       11.0
# 3                                       10.0
# 4                                        6.0
# ...                                      ...
# 23941                                   12.0
# 23942                                   13.0
# 23943                                   12.0
# 23944                                   12.0
# 23946                                    9.0
#
#        Social Emotional-Peer Interaction SS  \
# 0                                       NaN
# 1                                       9.0
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 23941                                  12.0
# 23942                                   NaN
# 23943                                  13.0
# 23944                                  10.0
# 23946                                   NaN
#
#        Social Emotional-Self Concept / Social Role SS  \
# 0                                                15.0
# 1                                                11.0
# 2                                                 6.0
# 3                                                11.0
# 4                                                 5.0
# ...                                               ...
# 23941                                             4.0
# 23942                                            12.0
# 23943                                            13.0
# 23944                                             9.0
# 23946                                            10.0
#
#        Communication-Receptive Communication SS  \
# 0                                           8.0
# 1                                          10.0
# 2                                           7.0
# 3                                           8.0
# 4                                           5.0
# ...                                         ...
# 23941                                      10.0
# 23942                                      12.0
# 23943                                      14.0
# 23944                                       4.0
# 23946                                       8.0
#
#        Communication-Expressive Communication SS  Motor-Gross Motor SS  \
# 0                                            9.0                   7.0
# 1                                            9.0                   7.0
# 2                                            7.0                  11.0
# 3                                            8.0                   5.0
# 4                                            5.0                   3.0
# ...                                          ...                   ...
# 23941                                        7.0                  10.0
# 23942                                       12.0                  11.0
# 23943                                       10.0                  15.0
# 23944                                        1.0                  11.0
# 23946                                       12.0                   8.0
#
#        Motor-Fine Motor SS  Motor-Perceptual Motor SS  \
# 0                      9.0                        NaN
# 1                     13.0                       11.0
# 2                     12.0                        NaN
# 3                     12.0                        NaN
# 4                      8.0                        NaN
# ...                    ...                        ...
# 23941                 14.0                       14.0
# 23942                 15.0                        NaN
# 23943                 11.0                       12.0
# 23944                 10.0                       11.0
# 23946                 12.0                        NaN
#
#        Cognitive-Attention and Memory SS  \
# 0                                    7.0
# 1                                    9.0
# 2                                    8.0
# 3                                   14.0
# 4                                    9.0
# ...                                  ...
# 23941                                9.0
# 23942                                9.0
# 23943                               13.0
# 23944                               10.0
# 23946                                7.0
#
#        Cognitive-Reasoning / Academic Skills SS  \
# 0                                           NaN
# 1                                          14.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 23941                                      13.0
# 23942                                       NaN
# 23943                                      14.0
# 23944                                       9.0
# 23946                                       NaN
#
#        Cognitive-Perception and Concepts SS  standard_deviation
# 0                                      13.0            3.218868
# 1                                       7.0            2.267383
# 2                                       7.0            2.185813
# 3                                      10.0            2.803767
# 4                                      10.0            2.279132
# ...                                     ...                 ...
# 23941                                  13.0            3.379804
# 23942                                  15.0            1.878238
# 23943                                  14.0            1.690850
# 23944                                  10.0            3.094660
# 23946                                  12.0            1.964971
#
# [12392 rows x 14 columns]

# %%
dataset_eligibility_evaluation_domains = dataset_eligibility_evaluation.loc[:, dataset_eligibility_evaluation.columns.str.contains('Sum of Scaled Scores')]

# %%
dataset_eligibility_evaluation_domains = dataset_eligibility_evaluation_domains.drop(columns=['BDI-3 Total Sum of Scaled Scores'])

# %%
dataset_eligibility_evaluation_domains['standard_deviation'] = dataset_eligibility_evaluation_domains.std(axis=1, numeric_only=True)

# %%
dataset_eligibility_evaluation_domains.describe()
# Out:
#        Adaptive Sum of Scaled Scores  Social-Emotional Sum of Scaled Scores  \
# count                    12386.00000                           12384.000000
# mean                        10.57460                              21.370236
# std                          5.25707                               6.985556
# min                          1.00000                               2.000000
# 25%                          7.00000                              17.000000
# 50%                         10.00000                              21.000000
# 75%                         13.00000                              26.000000
# max                         36.00000                              48.000000
#
#        Communication Sum of Scaled Scores  Motor Sum of Scaled Scores  \
# count                        12371.000000                12376.000000
# mean                            13.726700                   22.043229
# std                              6.420995                    7.378779
# min                              2.000000                    2.000000
# 25%                              9.000000                   17.000000
# 50%                             14.000000                   21.000000
# 75%                             19.000000                   27.000000
# max                             36.000000                   50.000000
#
#        Cognitive Sum of Scaled Scores  standard_deviation
# count                    12379.000000        12389.000000
# mean                        19.759674            7.666330
# std                          6.218461            2.039807
# min                          2.000000            0.621916
# 25%                         16.000000            6.198339
# 50%                         20.000000            7.436905
# 75%                         23.000000            9.042180
# max                         47.000000           16.670553

# %%
dataset_eligibility_evaluation_domains
# Out:
#        Adaptive Sum of Scaled Scores  Social-Emotional Sum of Scaled Scores  \
# 0                                7.0                                   29.0
# 1                               16.0                                   32.0
# 2                                8.0                                   17.0
# 3                               13.0                                   21.0
# 4                                5.0                                   11.0
# ...                              ...                                    ...
# 23941                           30.0                                   28.0
# 23942                           13.0                                   25.0
# 23943                           25.0                                   38.0
# 23944                           21.0                                   31.0
# 23946                           11.0                                   19.0
#
#        Communication Sum of Scaled Scores  Motor Sum of Scaled Scores  \
# 0                                    17.0                        16.0
# 1                                    19.0                        31.0
# 2                                    14.0                        23.0
# 3                                    16.0                        17.0
# 4                                    10.0                        11.0
# ...                                   ...                         ...
# 23941                                17.0                        38.0
# 23942                                24.0                        26.0
# 23943                                24.0                        38.0
# 23944                                 5.0                        32.0
# 23946                                20.0                        20.0
#
#        Cognitive Sum of Scaled Scores  BDI-3 Total Sum of Scaled Scores  \
# 0                                20.0                              89.0
# 1                                30.0                             128.0
# 2                                15.0                              77.0
# 3                                24.0                              91.0
# 4                                19.0                              56.0
# ...                               ...                               ...
# 23941                            35.0                             148.0
# 23942                            24.0                             112.0
# 23943                            41.0                             166.0
# 23944                            29.0                             118.0
# 23946                            19.0                              89.0
#
#        standard_deviation
# 0               29.917665
# 1               42.339895
# 2               25.609894
# 3               29.971097
# 4               18.832596
# ...                   ...
# 23941           48.873988
# 23942           36.887215
# 23943           54.690645
# 23944           39.832985
# 23946           29.268869
#
# [12392 rows x 7 columns]

# %%
dataset_eligibility_evaluation_adaptive = dataset_eligibility_evaluation[['Adaptive-Self Care SS', 'Adaptive-Personal Responsibility SS']]

# %%
dataset_eligibility_evaluation_adaptive.corr()
# Out:
#                                      Adaptive-Self Care SS  \
# Adaptive-Self Care SS                             1.000000
# Adaptive-Personal Responsibility SS               0.522434
#
#                                      Adaptive-Personal Responsibility SS
# Adaptive-Self Care SS                                           0.522434
# Adaptive-Personal Responsibility SS                             1.000000

# %%
dataset_eligibility_evaluation_communication = dataset_eligibility_evaluation[['Communication-Receptive Communication SS', 'Communication-Expressive Communication SS']]

# %%
dataset_eligibility_evaluation_communication['difference'] = dataset_eligibility_evaluation['Communication-Receptive Communication SS'] - dataset_eligibility_evaluation['Communication-Expressive Communication SS']
# Out:
# C:\Users\AaronH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_eligibility_evaluation_communication.describe()
# Out:
#        Communication-Receptive Communication SS  \
# count                              12382.000000
# mean                                   6.938621
# std                                    3.522957
# min                                    1.000000
# 25%                                    4.000000
# 50%                                    7.000000
# 75%                                   10.000000
# max                                   19.000000
#
#        Communication-Expressive Communication SS  standard_deviation  \
# count                                12374.00000        12371.000000
# mean                                     6.78964            1.595577
# std                                      3.54953            1.360892
# min                                      1.00000            0.000000
# 25%                                      4.00000            0.707107
# 50%                                      7.00000            1.414214
# 75%                                      9.00000            2.121320
# max                                     19.00000           11.313708
#
#          difference
# count  12371.000000
# mean       0.146552
# std        2.962216
# min      -14.000000
# 25%       -2.000000
# 50%        0.000000
# 75%        2.000000
# max       16.000000
